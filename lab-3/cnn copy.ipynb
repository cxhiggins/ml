# %% [markdown]
# <a href="https://colab.research.google.com/github/cxhiggins/ml/blob/master/cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TensorFlow versions in Colab

# %% [markdown]
# ##Background
# Colab has two versions of TensorFlow pre-installed: a 2.x version and a 1.x version. Colab uses TensorFlow 2.x by default, though you can switch to 1.x by the method shown below.

# %% [markdown]
# ##Specifying the TensorFlow version
#
# Running `import tensorflow` will import the default version (currently 2.x). You can use 1.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.4.0-rc0

# %% [markdown]
# If you want to switch TensorFlow versions after import, you **will need to restart your runtime** with 'Runtime' -> 'Restart runtime...' and then specify the version before you import it again.

# %% [markdown]
# ## Avoid Using ``pip install`` with GPUs and TPUs
#
# We recommend against using ``pip install`` to specify a particular TensorFlow version for both GPU and TPU backends. Colab builds TensorFlow from source to ensure compatibility with our fleet of accelerators. Versions of TensorFlow fetched from PyPI by ``pip`` may suffer from performance problems or may not work at all.

# %% [markdown]
# # Lab 3 Tests

# %%
from matplotlib import pylab
pylab.rcParams['figure.figsize'] = (10.0, 10.0)

# from tensorflow.examples.tutorials.mnist import input_data

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, initializers, optimizers

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.05)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()
# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
def one_hot(labels):
  return tf.one_hot(labels, len(np.unique(labels)))

# %%
train_labels = one_hot(train_labels)
test_labels = one_hot(test_labels)

# %%
# Let us visualise the first 16 data points from the MNIST training data

fig = plt.figure()
for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1)
    ax.set_xticks(())
    ax.set_yticks(())
    ax.imshow(train_images[i].reshape(28, 28), cmap='Greys_r')

# %%
model = models.Sequential()
model.add(layers.Conv2D(
    filters=25,
    kernel_size=(12, 12),
    strides=(2,2),
    activation='relu',
    input_shape=(28, 28, 1),
    padding='valid',  # uses no padding
    kernel_initializer=initializers.RandomNormal(mean=0, stddev=0.05),
    use_bias=True,
    bias_initializer=initializers.Constant(0.1)
))
model.add(layers.Conv2D(
    filters=64,
    kernel_size=(5, 5),
    strides=(1,1),
    activation='relu',
    padding='same'  # pads to maintain width and height
))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(
    units=1024,
    activation='relu'
))
model.add(layers.Dropout(
    rate=0.2
))
model.add(layers.Dense(
    units=10,
    activation='softmax'
))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 9, 9, 25)          3625
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 9, 9, 64)          40064
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 1,103,539
# Trainable params: 1,103,539
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(
        from_logits=False,
        label_smoothing=0, 
        reduction=tf.keras.losses.Reduction.SUM_OVER_BATCH_SIZE,
    ),
    metrics=['accuracy']
)

history = model.fit(
    train_images.reshape(60000, 28, 28, 1),
    train_labels,
    batch_size=50,
    steps_per_epoch=100,
    epochs=50, 
    validation_data=(test_images.reshape(10000, 28, 28, 1), test_labels)
)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 10s 95ms/step - loss: 1.8986 - accuracy: 0.4423 - val_loss: 0.5843 - val_accuracy: 0.8490
# Epoch 2/50
# 100/100 [==============================] - 11s 111ms/step - loss: 0.5870 - accuracy: 0.8245 - val_loss: 0.3836 - val_accuracy: 0.8883
# Epoch 3/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.4105 - accuracy: 0.8796 - val_loss: 0.3100 - val_accuracy: 0.9110
# Epoch 4/50
# 100/100 [==============================] - 10s 98ms/step - loss: 0.3257 - accuracy: 0.9005 - val_loss: 0.2596 - val_accuracy: 0.9264
# Epoch 5/50
# 100/100 [==============================] - 10s 100ms/step - loss: 0.3149 - accuracy: 0.9031 - val_loss: 0.2350 - val_accuracy: 0.9282
# Epoch 6/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2595 - accuracy: 0.9196 - val_loss: 0.2030 - val_accuracy: 0.9387
# Epoch 7/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.2498 - accuracy: 0.9279 - val_loss: 0.1799 - val_accuracy: 0.9461
# Epoch 8/50
# 100/100 [==============================] - 9s 90ms/step - loss: 0.2313 - accuracy: 0.9294 - val_loss: 0.1689 - val_accuracy: 0.9494
# Epoch 9/50
# 100/100 [==============================] - 9s 90ms/step - loss: 0.1987 - accuracy: 0.9402 - val_loss: 0.1485 - val_accuracy: 0.9556
# Epoch 10/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1639 - accuracy: 0.9434 - val_loss: 0.1366 - val_accuracy: 0.9599
# Epoch 11/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1682 - accuracy: 0.9474 - val_loss: 0.1219 - val_accuracy: 0.9645
# Epoch 12/50
# 100/100 [==============================] - 10s 97ms/step - loss: 0.1436 - accuracy: 0.9582 - val_loss: 0.1194 - val_accuracy: 0.9642
# Epoch 13/50
# 100/100 [==============================] - 10s 97ms/step - loss: 0.1382 - accuracy: 0.9598 - val_loss: 0.1164 - val_accuracy: 0.9639
# Epoch 14/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.1191 - accuracy: 0.9656 - val_loss: 0.1017 - val_accuracy: 0.9699
# Epoch 15/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.1377 - accuracy: 0.9603 - val_loss: 0.1041 - val_accuracy: 0.9676
# Epoch 16/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1407 - accuracy: 0.9572 - val_loss: 0.0992 - val_accuracy: 0.9695
# Epoch 17/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.1119 - accuracy: 0.9658 - val_loss: 0.0924 - val_accuracy: 0.9734
# Epoch 18/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.1189 - accuracy: 0.9621 - val_loss: 0.0880 - val_accuracy: 0.9719
# Epoch 19/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.1031 - accuracy: 0.9716 - val_loss: 0.0856 - val_accuracy: 0.9728
# Epoch 20/50
# 100/100 [==============================] - 10s 97ms/step - loss: 0.1026 - accuracy: 0.9653 - val_loss: 0.0839 - val_accuracy: 0.9747
# Epoch 21/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.0834 - accuracy: 0.9758 - val_loss: 0.0823 - val_accuracy: 0.9756
# Epoch 22/50
# 100/100 [==============================] - 10s 95ms/step - loss: 0.0963 - accuracy: 0.9671 - val_loss: 0.0802 - val_accuracy: 0.9749
# Epoch 23/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0957 - accuracy: 0.9705 - val_loss: 0.0739 - val_accuracy: 0.9754
# Epoch 24/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.1180 - accuracy: 0.9621 - val_loss: 0.0731 - val_accuracy: 0.9793
# Epoch 25/50
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0791 - accuracy: 0.9773 - val_loss: 0.0715 - val_accuracy: 0.9776
# Epoch 26/50
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0896 - accuracy: 0.9718 - val_loss: 0.0721 - val_accuracy: 0.9754
# Epoch 27/50
# 100/100 [==============================] - 9s 90ms/step - loss: 0.1035 - accuracy: 0.9703 - val_loss: 0.0795 - val_accuracy: 0.9746
# Epoch 28/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.0798 - accuracy: 0.9771 - val_loss: 0.0685 - val_accuracy: 0.9790
# Epoch 29/50
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0837 - accuracy: 0.9736 - val_loss: 0.0625 - val_accuracy: 0.9808
# Epoch 30/50
# 100/100 [==============================] - 9s 95ms/step - loss: 0.0701 - accuracy: 0.9759 - val_loss: 0.0679 - val_accuracy: 0.9785
# Epoch 31/50
# 100/100 [==============================] - 10s 95ms/step - loss: 0.0741 - accuracy: 0.9755 - val_loss: 0.0615 - val_accuracy: 0.9800
# Epoch 32/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0890 - accuracy: 0.9729 - val_loss: 0.0681 - val_accuracy: 0.9797
# Epoch 33/50
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0616 - accuracy: 0.9819 - val_loss: 0.0584 - val_accuracy: 0.9830
# Epoch 34/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.0850 - accuracy: 0.9753 - val_loss: 0.0579 - val_accuracy: 0.9815
# Epoch 35/50
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0620 - accuracy: 0.9781 - val_loss: 0.0629 - val_accuracy: 0.9795
# Epoch 36/50
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0949 - accuracy: 0.9704 - val_loss: 0.0575 - val_accuracy: 0.9826
# Epoch 37/50
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0696 - accuracy: 0.9818 - val_loss: 0.0575 - val_accuracy: 0.9822
# Epoch 38/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0529 - accuracy: 0.9857 - val_loss: 0.0582 - val_accuracy: 0.9816
# Epoch 39/50
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0695 - accuracy: 0.9831 - val_loss: 0.0666 - val_accuracy: 0.9792
# Epoch 40/50
# 100/100 [==============================] - 10s 95ms/step - loss: 0.0593 - accuracy: 0.9820 - val_loss: 0.0507 - val_accuracy: 0.9840
# Epoch 41/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0591 - accuracy: 0.9794 - val_loss: 0.0476 - val_accuracy: 0.9857
# Epoch 42/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0865 - accuracy: 0.9805 - val_loss: 0.0581 - val_accuracy: 0.9814
# Epoch 43/50
# 100/100 [==============================] - 10s 95ms/step - loss: 0.0591 - accuracy: 0.9818 - val_loss: 0.0520 - val_accuracy: 0.9835
# Epoch 44/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0641 - accuracy: 0.9829 - val_loss: 0.0586 - val_accuracy: 0.9803
# Epoch 45/50
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0793 - accuracy: 0.9761 - val_loss: 0.0480 - val_accuracy: 0.9841
# Epoch 46/50
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0632 - accuracy: 0.9789 - val_loss: 0.0463 - val_accuracy: 0.9855
# Epoch 47/50
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0515 - accuracy: 0.9808 - val_loss: 0.0432 - val_accuracy: 0.9865
# Epoch 48/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0711 - accuracy: 0.9785 - val_loss: 0.0618 - val_accuracy: 0.9815
# Epoch 49/50
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0548 - accuracy: 0.9832 - val_loss: 0.0450 - val_accuracy: 0.9865
# Epoch 50/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0521 - accuracy: 0.9831 - val_loss: 0.0457 - val_accuracy: 0.9863

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images.reshape(10000, 28, 28, 1),  test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.0457 - accuracy: 0.1061

# %% [markdown]
# With minibatches of size 50 and 5000 iterations (50 epochs of 100 iterations each), the accuracy with this model is 0.9891999959945679!
#
# ---

# %%
def visualize_prediction(image_data):
  assert(len(image_data) >= 16)
  predictions = list(map(np.argmax, model.predict(image_data[:16].reshape(16, 28, 28, 1))))

  fig = plt.figure()
  for i in range(16):
      ax = fig.add_subplot(4, 4, i + 1)
      ax.set_xticks(())
      ax.set_yticks(())
      ax.imshow(image_data[i].reshape(28, 28), cmap='Greys_r')
      ax.set_xlabel(predictions[i])

  fig.subplots_adjust(hspace=0.4)

# %%
# Let us visualise the first 16 data points from the MNIST training data
visualize_prediction(test_images[16:32])

# %% [markdown]
# ##### Unused prewritten code from the skeleton

# %%
tf.disable_v2_behavior()

x = tf.placeholder(tf.float32, shape=[None, 784])
x_ = tf.reshape(x, [-1, 28, 28, 1])
y_ = tf.placeholder(tf.float32, shape=[None, 10])

# Define the first convolution layer here
# TODO
# W_conv1 =
# b_conv1 = 
# h_conv1 = 

# Define the second convolution layer here
# W_conv2 = 
# b_conv2 = 
# h_conv2 = 

# Define maxpooling
# h_pool2 = 

# All subsequent layers will be fully connected ignoring geometry so we'll flatten the layer
# Flatten the h_pool2_layer (as it has a multidimensiona shape) 
# h_pool2_flat = 

# Define the first fully connected layer here
# W_fc1 = 
# b_fc1 = 
# h_fc1 = 

# Use dropout for this layer (should you wish)
# keep_prob = tf.placeholder(tf.float32)
# h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# The final fully connected layer
# W_fc2 = 
# b_fc2 = 
# y_conv =
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# We'll use the cross entropy loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_conv, labels=y_))

# And classification accuracy
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# And the Adam optimiser
train_step = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(cross_entropy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-10e0b012a53a> in <module>()
#       1 # We'll use the cross entropy loss function
# ----> 2 cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_conv, labels=y_))
#       3
#       4 # And classification accuracy
#       5 correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
#
# NameError: name 'y_conv' is not defined
